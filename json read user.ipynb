# %%
import gzip
import pandas as pd
import json
from collections import defaultdict
import itertools

data_users3 = []
        
        
with gzip.open('D:/Vortess/DWH/10_Datasets/Google Local Review/users.clean.json.gz') as g:
    for line in itertools.islice(g, 0, 3747937):        
        data_users3.append(eval(line))
        
df2 = pd.DataFrame.from_dict(data_users3)

# %%
num_lines = sum(1 for line in gzip.open('D:/Vortess/DWH/10_Datasets/Google Local Review/users.clean.json.gz'))
# Out:
# 3747937

# %%
df2
#print(df2.dtypes)
# Out:
#                  userName                                               jobs  \
# 0                  an lam  [[Tổng công ty IDICO, Chuyên viên Kỹ thuật XD,...
# 1            HALİL TURGUT  [[Mustafa Nevzat İlaç San. A.Ş., Rebrezant, []...
# 2                   森田さとこ                                               None
# 3               amey kore                                               None
# 4        william spindler                                               None
# ...                   ...                                                ...
# 3747932     Andrei Mustea                                               None
# 3747933      ahmed alalam                                               None
# 3747934      Brad Shaffer                                               None
# 3747935    Ashley Krueger                                               None
# 3747936       kadir çöpür                                               None
#
# ...

# %%
import pyodbc
server = '192.168.220.220'
database = 'Sandbox' 
username = 'tjuhasz' 
password = 'M3dvECuk0rk@d0B0zb@n' 
import sqlalchemy


engine = sqlalchemy.create_engine(
               "mssql+pyodbc://tjuhasz:M3dvECuk0rk@d0B0zb@n@192.168.220.220/Sandbox",
               echo=False)
#cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

df2.to_sql(
    name='google_useres',
    con = engine,
    index = False,
    if_exists = 'append'
)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
df2.to_csv(r'users.csv',sep = ',',index = None)
